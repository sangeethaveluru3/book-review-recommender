# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import dask.dataframe as dd

# %% [markdown]
# ### Load the full dataframe

# %%
df = pd.read_csv('/Volumes/external/Sangeetha-Project/Original files/reviews1.csv.zip', compression = 'zip',
                 names=['reviwerId', 'asin', 'review', 'rating',
                        'summary', 'unixtime', 'pos_votes', 'total_votes']) \
    .drop(columns=['review', 'summary', 'unixtime', 'pos_votes', 'total_votes']) \
    .astype({'rating': 'int8'})

# %%
df.head()
# Out:
#                reviwerId        asin  rating
# 0  A10000012B7CGYKOMPQ4L  000100039X       5
# 1         A2S166WSCFIFP5  000100039X       5
# 2         A1BM81XB4QHOA3  000100039X       5
# 3         A1MOSTXNIO5MPJ  000100039X       5
# 4         A2XQ5LZHTD4AFT  000100039X       5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3010000 entries, 0 to 3009999
# Data columns (total 3 columns):
# reviwerId    object
# asin         object
# rating       int8
# dtypes: int8(1), object(2)
# memory usage: 48.8+ MB

# %% [markdown]
# ### Checking the density of the data

# %%
print('Reviewers under 5: ', (df.reviwerId.value_counts() < 5).mean())
print('Mean reviewers: ', df.reviwerId.value_counts().mean())
print('Median reviewers: ', df.reviwerId.value_counts().median())
print('-----------------------------------------------')
print('Books under 5: ', (df.asin.value_counts() < 5).mean())
print('Mean books: ', df.asin.value_counts().mean())
print('Median books: ', df.asin.value_counts().median())
# Out:
# Reviewers under 5:  0.6687836133393875
# Mean reviewers:  6.074365571868221
# Median reviewers:  3.0
# -----------------------------------------------
# Books under 5:  0.0
# Mean books:  32.62978741856104
# Median books:  12.0

# %%
id_counts = df.reviwerId.value_counts()
id_counts
# Out:
# AFVQZQ8PW0L       14072
# A14OJS0VWMOSWO     3884
# A2F6N60Z96CAJI     3852
# A1K1JW1C5CUSUZ     1814
# A320TMDV6KCFU      1718
#                   ...
# AOX748JW0I28R         1
# AXIXQEGLL4VMO         1
# A2J14AK9URRP76        1
# A1Q4F7N5P880EO        1
# A2B3QVGHNDFUQW        1
# Name: reviwerId, Length: 495525, dtype: int64

# %%
book_counts= df.asin.value_counts()
book_counts
# Out:
# 030758836X    7440
# 0439023483    6717
# 0375831002    4864
# 038536315X    4604
# 0439023513    4440
#               ...
# 0441712347       5
# 0393323994       5
# 0345431820       5
# 0373812167       5
# 0312319304       5
# Name: asin, Length: 92247, dtype: int64

# %% [markdown]
# ### Attempting to make the data denser

# %%
id_counts_remove = list(id_counts[id_counts <3].index)
print(len(id_counts_remove))
id_counts_remove[:5]
# Out:
# 189424
# ['A2V1NBLN9MUG4A',
#  'A3419POCSDI5FO',
#  'A1MHTZNZT97D6H',
#  'A24IMAYPSKXB5N',
#  'A1AFQWG2H2H7BT']

# %%
df[df.reviwerId.isin(id_counts_remove)]
# Out:
#               reviwerId        asin  rating
# 2        A1BM81XB4QHOA3  000100039X       5
# 8        A3FI0744PG1WYG  000100039X       5
# 24        AUTNO7VDY4H4A  000100039X       5
# 41       A3BHSR8LON67NA  000100039X       5
# 52        AW1Z7GYIBWB4K  000100039X       5
# ...                 ...         ...     ...
# 3009988  A3I044ICARNZK5  0578124114       5
# 3009992   A36ZD9ZRVXQGQ  0578124114       5
# 3009994   AQN0BSMCD7W1W  0578124114       5
# 3009996  A2N513SD0BR6VC  0578124114       5
# 3009998   AGPSU8WMSWFCZ  0578124114       5
#
# [281360 rows x 3 columns]

# %%
df_dense = df.drop(index = df[df.reviwerId.isin(id_counts_remove)].index)

# %% [markdown]
# ### Analysing the denser dataframe

# %%
df_dense.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2728640 entries, 0 to 3009999
# Data columns (total 3 columns):
# reviwerId    object
# asin         object
# rating       int8
# dtypes: int8(1), object(2)
# memory usage: 65.1+ MB

# %%
print('Reviewers under 5: ', (df_dense.reviwerId.value_counts() < 5).mean())
print('Mean reviewers: ', df_dense.reviwerId.value_counts().mean())
print('Median reviewers: ', df_dense.reviwerId.value_counts().median())
print('-----------------------------------------------')
print('Books under 5: ', (df_dense.asin.value_counts() < 5).mean())
print('Mean books: ', df_dense.asin.value_counts().mean())
print('Median books: ', df_dense.asin.value_counts().median())
# Out:
# Reviewers under 5:  0.4638174981460368
# Mean reviewers:  8.914181920346552
# Median reviewers:  5.0
# -----------------------------------------------
# Books under 5:  0.06259485711807813
# Mean books:  29.580677334027147
# Median books:  11.0

# %%
df_dense.asin.value_counts()
# Out:
# 030758836X    6613
# 0439023483    5766
# 0375831002    4199
# 038536315X    3962
# 0316055433    3907
#               ...
# 0557482305       1
# 0345498143       1
# 0545237459       1
# 0385267029       1
# 0240820606       1
# Name: asin, Length: 92244, dtype: int64

# %%
df_dense.reviwerId.value_counts()
# Out:
# AFVQZQ8PW0L       14072
# A14OJS0VWMOSWO     3884
# A2F6N60Z96CAJI     3852
# A1K1JW1C5CUSUZ     1814
# A320TMDV6KCFU      1718
#                   ...
# A13AMTIGRKFG9K        3
# AY7S97W40WAXJ         3
# A22E78WHDI2AUZ        3
# A17S3074CRAMZP        3
# A2F87G3MVXRLNT        3
# Name: reviwerId, Length: 306101, dtype: int64

# %%
len(df_dense.asin.unique())
# Out:
# 92244

# %%
len(df_dense.reviwerId.unique())
# Out:
# 306101

# %% [markdown]
# ### Attempting to write this new dataframe to csv

# %%
dense_index = df_dense.index
dense_index
# Out:
# Int64Index([      0,       1,       3,       4,       5,       6,       7,
#                   9,      10,      11,
#             ...
#             3009985, 3009986, 3009987, 3009989, 3009990, 3009991, 3009993,
#             3009995, 3009997, 3009999],
#            dtype='int64', length=2728640)

# %%
df.loc[dense_index]
# Out:
#                      reviwerId        asin  rating
# 0        A10000012B7CGYKOMPQ4L  000100039X       5
# 1               A2S166WSCFIFP5  000100039X       5
# 3               A1MOSTXNIO5MPJ  000100039X       5
# 4               A2XQ5LZHTD4AFT  000100039X       5
# 5               A3V1MKC2BVWY48  000100039X       5
# ...                        ...         ...     ...
# 3009991         A2U7WBWEY9LV1K  0578124114       5
# 3009993         A1U1B6KJPGA4IP  0578124114       4
# 3009995         A33KNBGC6UM133  0578124114       3
# 3009997         A11VVB5KUO817E  0578124114       5
# 3009999         A2V6KMOJUVFY8A  0578124114       5
#
# [2728640 rows x 3 columns]

# %%
df
# Out:
#                      reviwerId        asin  rating
# 0        A10000012B7CGYKOMPQ4L  000100039X       5
# 1               A2S166WSCFIFP5  000100039X       5
# 2               A1BM81XB4QHOA3  000100039X       5
# 3               A1MOSTXNIO5MPJ  000100039X       5
# 4               A2XQ5LZHTD4AFT  000100039X       5
# ...                        ...         ...     ...
# 3009995         A33KNBGC6UM133  0578124114       3
# 3009996         A2N513SD0BR6VC  0578124114       5
# 3009997         A11VVB5KUO817E  0578124114       5
# 3009998          AGPSU8WMSWFCZ  0578124114       5
# 3009999         A2V6KMOJUVFY8A  0578124114       5
#
# [3010000 rows x 3 columns]

# %%
reader = pd.read_csv('/Volumes/external/Sangeetha-Project/Original files/reviews1.csv.zip', compression='zip',
                 names=['reviwerId', 'asin', 'review', 'rating',
                        'summary', 'unixtime', 'pos_votes', 'total_votes'], chunksize = 10000)
counter= 10000
prev = 0
for temp_df in reader:
    
    indices_to_keep = list(df_dense.loc[prev:counter].index)
    print(len(indices_to_keep), min(indices_to_keep), max(indices_to_keep))
    
    temp_df.loc[temp_df.index.intersection(indices_to_keep)].to_csv('/Volumes/external/Sangeetha-Project/book_reviews.csv', 
              columns = ['reviwerId', 'asin', 'review', 'rating',
                        'summary', 'unixtime', 'pos_votes', 'total_votes'],
                          header=False, mode = 'a', index=False)
    print(prev, counter)
    prev = counter+1
    counter+=10000
# Out:
# 9037 0 10000
# 0 10000
# 9254 10001 20000
# 10001 20000
# 8801 20001 30000
# 20001 30000
# 8423 30002 39998
# 30001 40000
# 8803 40002 50000
# 40001 50000
# 9107 50002 60000
# 50001 60000
# 9283 60001 70000
# 60001 70000
# 9173 70001 80000
# 70001 80000
# 9196 80002 90000
# 80001 90000
# 9263 90001 100000
# 90001 100000
# 9240 100001 110000
# 100001 110000
# 9268 110001 120000
# 110001 120000
# 8983 120001 130000
# 120001 130000
# 9173 130001 140000
# 130001 140000
# 9139 140001 150000
# 140001 150000
# 9176 150001 159999
# 150001 160000
# 9271 160001 170000
# 160001 170000
# 9166 170001 180000
# 170001 180000
# 9151 180001 189999
# 180001 190000
# 9143 190001 200000
# 190001 200000
# 9224 200001 210000
# 200001 210000
# 9225 210001 220000
# 210001 220000
# 9184 220001 230000
# 220001 230000
# 9192 230001 240000
# 230001 240000
# 9157 240001 250000
# 240001 250000
# 9162 250001 260000
# 250001 260000
# 9154 260001 270000
# 260001 270000
# 9176 270001 280000
# 270001 280000
# 9244 280001 290000
# 280001 290000
# 9247 290001 300000
# 290001 300000
# 9144 300001 310000
# 300001 310000
# 9165 310002 320000
# 310001 320000
# 9170 320001 330000
# 320001 330000
# 9172 330001 340000
# 330001 340000
# 8916 340001 350000
# 340001 350000
# 9003 350001 359999
# 350001 360000
# 9076 360003 370000
# 360001 370000
# 9209 370001 380000
# 370001 380000
# 9039 380001 390000
# 380001 390000
# 9014 390001 400000
# 390001 400000
# 9250 400001 410000
# 400001 410000
# 8853 410001 420000
# 410001 420000
# 9039 420001 430000
# 420001 430000
# 9094 430001 439999
# 430001 440000
# 8881 440001 450000
# 440001 450000
# 8919 450001 460000
# 450001 460000
# 8998 460002 470000
# 460001 470000
# 8321 470001 480000
# 470001 480000
# 8714 2600001 2610000
# 2600001 2610000
# 9146 2610003 2620000
# 2610001 2620000
# 9347 2620001 2630000
# 2620001 2630000
# 9341 2630001 2640000
# 2630001 2640000
# 9149 2640001 2650000
# 2640001 2650000
# 8758 2650001 2660000
# 2650001 2660000
# 8845 2660001 2670000
# 2660001 2670000
# 8499 2670001 2680000
# 2670001 2680000
# 9439 2680001 2690000
# 2680001 2690000
# 8501 2690001 2700000
# 2690001 2700000
# 9180 2700001 2710000
# 2700001 2710000
# 9049 2710001 2720000
# 2710001 2720000
# 9187 2720001 2730000
# 2720001 2730000
# 8768 2730001 2740000
# 2730001 2740000
# 8510 2740001 2750000
# 2740001 2750000
# 8416 2750001 2760000
# 2750001 2760000
# 8621 2760001 2770000
# 2760001 2770000
# 8549 2770001 2780000
# 2770001 2780000
# 8585 2780001 2790000
# 2780001 2790000
# 8620 2790001 2800000
# 2790001 2800000
# 8377 2800001 2810000
# 2800001 2810000
# 9098 2810001 2820000
# 2810001 2820000
# 8890 2820001 2830000
# 2820001 2830000
# 9120 2830001 2840000
# 2830001 2840000
# 8872 2840001 2849997
# 2840001 2850000
# 8773 2850001 2860000
# 2850001 2860000
# 9005 2860001 2870000
# 2860001 2870000
# 8856 2870001 2880000
# 2870001 2880000
# 9145 2880001 2890000
# 2880001 2890000
# 9436 2890001 2900000
# 2890001 2900000
# 9120 2900001 2910000
# 2900001 2910000
# 8807 2910001 2920000
# 2910001 2920000
# 9240 2920001 2929998
# 2920001 2930000
# 9205 2930002 2940000
# 2930001 2940000
# 8814 2940001 2950000
# 2940001 2950000
# 9292 2950002 2960000
# 2950001 2960000
# 9497 2960001 2970000
# 2960001 2970000
# 9424 2970001 2980000
# 2970001 2980000
# 9119 2980001 2990000
# 2980001 2990000
# 7833 2990001 3000000
# 2990001 3000000
# 7601 3000001 3009999
# 3000001 3010000

# %% [markdown]
# ### Testing the csv file to see if the copy went well

# %%
test_df = pd.read_csv('/Volumes/external/Sangeetha-Project/book_reviews.csv',
                 names=['reviwerId', 'asin', 'review', 'rating',
                        'summary', 'unixtime', 'pos_votes', 'total_votes']) \
    .drop(columns=['review', 'summary', 'unixtime','total_votes']).astype({'rating':'int8'})

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2728360 entries, 0 to 2728359
# Data columns (total 4 columns):
# reviwerId    object
# asin         object
# rating       int8
# pos_votes    int64
# dtypes: int64(1), int8(1), object(2)
# memory usage: 65.0+ MB

# %%
test_df[test_df.rating.isnull()]
# Out:
# Empty DataFrame
# Columns: [reviwerId, asin, rating, pos_votes]
# Index: []

# %%
print('Reviewers under 5: ', (test_df.reviwerId.value_counts() < 5).mean())
print('Mean reviewers: ', test_df.reviwerId.value_counts().mean())
print('Median reviewers: ', test_df.reviwerId.value_counts().median())
print('-----------------------------------------------')
print('Books under 5: ', (test_df.asin.value_counts() < 5).mean())
print('Mean books: ', test_df.asin.value_counts().mean())
print('Median books: ', test_df.asin.value_counts().median())
# Out:
# Reviewers under 5:  0.4638991705352155
# Mean reviewers:  8.913267189587751
# Median reviewers:  5.0
# -----------------------------------------------
# Books under 5:  0.06267074281254065
# Mean books:  29.577641906248644
# Median books:  11.0

# %%
test_df.describe()
# Out:
#              rating     pos_votes
# count  2.728360e+06  2.728360e+06
# mean   4.153319e+00  3.821344e+00
# std    1.104071e+00  2.808396e+01
# min    1.000000e+00  0.000000e+00
# 25%    4.000000e+00  0.000000e+00
# 50%    5.000000e+00  1.000000e+00
# 75%    5.000000e+00  2.000000e+00
# max    5.000000e+00  2.331100e+04

# %%
test_df.pos_votes.max()
# Out:
# 23311

# %% [markdown]
# ### Cleaning the negative values of the pos_votes and total_votes

# %%
test_df.loc[95:110]
# Out:
#           reviwerId        asin  rating  pos_votes
# 95    AMFSDTN7LJ4EM  000100039X       5          1
# 96   A3Q5B6YEMGK4HI  000100039X       5          0
# 97    AYZLXLVMJGTJV  000100039X       5          1
# 98    AG74166FELW9U  000100039X       5          0
# 99   A2ZZHMT58ZMVCZ  000100039X       5        -49
# 100   A5K32C2QZN3WL  000100039X       4          4
# 101  A1VSHT4FFP768T  000100039X       5          2
# 102   A4KYR93C6D5AI  000100039X       5          1
# 103    AQDD7PB1Z8ND  000100039X       5          0
# 104  A157UENZPTI1TD  000100039X       5          0
# 105  A3W43PSHRIG8KV  000100039X       4       -100
# 106  A1P5UBFPQ48OWN  000100039X       5          4
# 107   AACNFH28C1ZHB  000100039X       2         10
# 108   AO3IVXXU3T4R3  000100039X       5          0
# 109  A2I0AOWKGCU6M1  000100039X       5          1
# 110  A2OKG8UA0G4OXS  000100039X       5          0

# %%
test_df[test_df.pos_votes < 0]
# Out:
#               reviwerId        asin  rating  pos_votes
# 99       A2ZZHMT58ZMVCZ  000100039X       5        -49
# 105      A3W43PSHRIG8KV  000100039X       4       -100
# 1163     A2PR6NXG0PA3KY  0002007770       2        -55
# 1497      ALLJT7S5QOFFZ  0002007770       3        -40
# 1640     A22ABFEL815EY7  0002007770       3        -18
# ...                 ...         ...     ...        ...
# 2724046   A7H4LNXXJ3DM6  0575088885       3        -31
# 2724343  A3DQWFWINN3V5A  0575097469       5       -109
# 2725911  A259Q7R79WRGOY  0578032147       2        -69
# 2725979  A2X7NBUETXC19E  0578032147       5       -102
# 2726916  A2ZZHMT58ZMVCZ  0578061112       5        -32
#
# [5338 rows x 4 columns]

# %%
df[(df.reviwerId == 'A2ZZHMT58ZMVCZ')&(df.asin == '000100039X')]
# Out:
#           reviwerId        asin  rating
# 114  A2ZZHMT58ZMVCZ  000100039X       5

# %%
check_df = df = pd.read_csv('/Volumes/external/Sangeetha-Project/Original files/reviews1.csv.zip', compression = 'zip',
                 names=['reviwerId', 'asin', 'review', 'rating',
                        'summary', 'unixtime', 'pos_votes', 'total_votes'], nrows = 1000) \
    .drop(columns=['review', 'summary', 'unixtime']) \
    .astype({'rating': 'int8', 'pos_votes': 'int8', 'total_votes': 'int8'})

# %%
check_df[(check_df.reviwerId == 'A2ZZHMT58ZMVCZ')&(check_df.asin == '000100039X')]
# Out:
#           reviwerId        asin  rating  pos_votes  total_votes
# 114  A2ZZHMT58ZMVCZ  000100039X       5        -49          -41

# %%
import gzip 

data = []
counter = 0

with gzip.open('/Users/Sangeetha/Downloads/reviews_Books_5.json.gz') as f:
    for l in f:
        #To limit the number of rows
        if counter < 1000:
            data.append(json.loads(l.strip()))
            counter+=1
        else: 
            break

    og_df = pd.DataFrame.from_dict(data)

# %%
og_df.head()
# Out:
#               reviewerID        asin  \
# 0  A10000012B7CGYKOMPQ4L  000100039X
# 1         A2S166WSCFIFP5  000100039X
# 2         A1BM81XB4QHOA3  000100039X
# 3         A1MOSTXNIO5MPJ  000100039X
# 4         A2XQ5LZHTD4AFT  000100039X
#
#                                       reviewerName helpful  \
# 0                                             Adam  [0, 0]
# 1  adead_poet@hotmail.com "adead_poet@hotmail.com"  [0, 2]
# 2                      Ahoro Blethends "Seriously"  [0, 0]
# 3                                        Alan Krug  [0, 0]
# 4                                         Alaturka  [7, 9]
#
#                                           reviewText  overall  \
# 0  Spiritually and mentally inspiring! A book tha...      5.0
# 1  This is one my must have books. It is a master...      5.0
# 2  This book provides a reflection that you can a...      5.0
# 3  I first read THE PROPHET in college back in th...      5.0
# 4  A timeless classic.  It is a very demanding an...      5.0
#
#                                              summary  unixReviewTime  \
# 0                                         Wonderful!      1355616000
# 1                                       close to god      1071100800
# 2                    Must Read for Life Afficianados      1390003200
# 3  Timeless for every good and bad time in your l...      1317081600
# 4                                      A Modern Rumi      1033948800
#
#     reviewTime
# 0  12 16, 2012
# 1  12 11, 2003
# 2  01 18, 2014
# 3  09 27, 2011
# 4   10 7, 2002

# %%
og_df[(og_df.reviewerID == 'A2ZZHMT58ZMVCZ')&(og_df.asin == '000100039X')]
# Out:
#          reviewerID        asin            reviewerName     helpful  \
# 114  A2ZZHMT58ZMVCZ  000100039X  L. Power "nlp trainer"  [207, 215]
#
#                                             reviewText  overall  \
# 114  A prophet has waited twelve years in a coastal...      5.0
#
#                          summary  unixReviewTime   reviewTime
# 114  Deeper than you can imagine      1137456000  01 17, 2006

# %%
og_df[(og_df.reviewerID == 'A3W43PSHRIG8KV')&(og_df.asin == '000100039X')]
# Out:
#          reviewerID        asin reviewerName     helpful  \
# 120  A3W43PSHRIG8KV  000100039X   Mary Seale  [156, 167]
#
#                                             reviewText  overall  \
# 120  I first became aware of Kahlil Gibran when I r...      4.0
#
#               summary  unixReviewTime  reviewTime
# 120  Insightful Prose       957571200  05 6, 2000

# %%
og_df_subset = og_df.loc[95:125].copy()

# %%
og_df_subset
# Out:
#          reviewerID        asin  \
# 95    AAFLZI7MX9UIG  000100039X
# 96    A1FQPOYRBTTK1  000100039X
# 97   A1JBOMEZBH80JU  000100039X
# 98    A2DFYTW62P25Z  000100039X
# 99   A2MPRPCAQLTR3L  000100039X
# 100   A2W6WXEUAVM3E  000100039X
# 101   A7GT0WQKKDP0V  000100039X
# 102   ATAPOART4QGVO  000100039X
# 103  A2052JNVUPRTMT  000100039X
# 104   ADT39C7GOEAWW  000100039X
# 105   ASW9FWXSGKV2C  000100039X
# 106   AGKPTMTR3UX1R  000100039X
# 107  A1HS49P9TZRGV9  000100039X
# 108   AMFSDTN7LJ4EM  000100039X
# 109  A3Q5B6YEMGK4HI  000100039X
# 110  A2W4TXYV1M7FQ4  000100039X
# 111   AYZLXLVMJGTJV  000100039X
# 112   AG74166FELW9U  000100039X
# 113  A2W53LAQBPR831  000100039X
# 114  A2ZZHMT58ZMVCZ  000100039X
# 115   A5K32C2QZN3WL  000100039X
# 116  A1VSHT4FFP768T  000100039X
# 117   A4KYR93C6D5AI  000100039X
# 118    AQDD7PB1Z8ND  000100039X
# 119  A157UENZPTI1TD  000100039X
# 120  A3W43PSHRIG8KV  000100039X
# 121  A3HLNFF21USD1K  000100039X
# 122  A1P5UBFPQ48OWN  000100039X
# 123   AACNFH28C1ZHB  000100039X
# 124   AO3IVXXU3T4R3  000100039X
# 125   ANWMXAZZR2J0A  000100039X
#
#                                          reviewerName     helpful  \
# 95                                       J. M. DELEON      [0, 0]
# 96   John H. Eagan "Author: The Enlightenment, Wha...      [0, 0]
# 97   Joshua A. "I love switching back and forth be...      [0, 0]
# 98                               J. R. Willoughby DDS      [0, 0]
# 99   Judith Land "Adoption Detective | First Lilac...      [0, 0]
# 100                                           JuJuBee      [3, 5]
# 101  Julie Jordan Scott "Writer, Life Coach - Owne...      [2, 2]
# 102                                              Kate     [3, 15]
# 103                                       Kathy Adams   [97, 103]
# 104                               Kenny "crochet guy"      [0, 0]
# 105                                         Ken Smith      [0, 0]
# 106          Konrei "Everything I need is right here"    [17, 20]
# 107                                              KRLA      [7, 9]
# 108                                          Kwan Yin      [1, 2]
# 109                                   Lesley Oliverio      [0, 0]
# 110  Linda Demaria Schierberg "SUNBIRD FLIES BACK ...      [0, 0]
# 111                                         L. J Nary      [1, 1]
# 112                                              loni      [0, 1]
# 113                                         Lovebooks      [1, 1]
# 114                            L. Power "nlp trainer"  [207, 215]
# 115                              L. S. Cohen "Writer"      [4, 5]
# 116                                              MadG      [2, 2]
# 117                                   Marilyn Harding      [1, 1]
# 118                                              Mark      [0, 0]
# 119                                           martina      [0, 0]
# 120                                        Mary Seale  [156, 167]
# 121                Maureen A. Wilkie "mo in michigan"     [0, 56]
# 122                                       McGuffy Ann      [4, 4]
# 123                                         M. Chabot    [10, 28]
# 124                                         megtaylor      [0, 0]
# 125                   Mr. Barry C. Thompson "Barthom"      [0, 0]
#
#                                             reviewText  overall  \
# 95   Slow reading but full of Significant messages....      5.0
# 96   The Prophet by Kahlil Gibran is a book that's ...      5.0
# 97   This is a classic of world literature.  Everyo...      5.0
# 98   I was in my twenties when I first read The Pro...      5.0
# 99   A book to be treasured. A tremendous poet deal...      5.0
# 100  I read it in an hour. Kahlil Gibran is definit...      5.0
# 101  Reading a classic such as &quot;The Prophet&qu...      5.0
# 102  Maybe I just wasn't in the right mood for a he...      3.0
# 103  Gibran gets right down to the bedrock of what ...      5.0
# 104  The book came in great condition, as well as, ...      4.0
# 105  A short and magnificent book that will forever...      5.0
# 106  Kahlil Gibran (1883-1931), the Lebanese-Americ...      5.0
# 107  My father has this huge book collection and I ...      5.0
# 108  This is Kahlil Gibran at his best.  The prophe...      5.0
# 109  My favorite book.  I used the passaged in my w...      5.0
# 110  received on time and thank you for rel good on...      5.0
# 111  This book takes different themes such as work,...      5.0
# 112  "A brilliant man's philosophy on love, marriag...      5.0
# 113  I wanted the book the Prophet as an anniversar...      4.0
# 114  A prophet has waited twelve years in a coastal...      5.0
# 115  This book was the first and only I've read by ...      4.0
# 116  Everyone carries an omnificent quality within ...      5.0
# 117  Since I first read The Prophet when I was a te...      5.0
# 118  I have been reading The Prophet every year for...      5.0
# 119  Needed to read this and could not find my old ...      5.0
# 120  I first became aware of Kahlil Gibran when I r...      4.0
# 121  I appreciate getting the book at the great pri...      1.0
# 122  I first read this book as a teenager. It has r...      5.0
# 123  I picked up this book after being inspired by ...      2.0
# 124  This was my favorite book when i was 19! So I ...      5.0
# 125  Great read! A book for the ages! Each little p...      5.0
#
#                                                summary  unixReviewTime  \
# 95                                           Wonderful      1381104000
# 96                                    Interesting book      1235865600
# 97   A must read for every young person, a joy and ...      1385942400
# 98                                Through four decades      1402704000
# 99                       Equalled only by Shakespeare!      1310688000
# 100                                           Timeless      1046304000
# 101                  To Be Experienced as Well as Read      1065139200
# 102                                     Now I'm Sleepy      1183420800
# 103                                        Pure Wisdom       973814400
# 104                                         Satisfied.      1312588800
# 105                                        None Better      1394323200
# 106                           "People of Orphalese..."      1176076800
# 107                                        My Bible...      1095379200
# 108                                        Spectacular       951004800
# 109                         A beautiful spiritual book      1396828800
# 110  satisfied good ole book in the condition you t...      1299715200
# 111          Helpful Tool in gaining insight to spirit      1280275200
# 112               Inspiringly simple but also deep ...      1198886400
# 113                       Found what I was looking for      1342915200
# 114                        Deeper than you can imagine      1137456000
# 115    Chapters and Chapters of Insight and Revelation      1100649600
# 116                        A book that creates change.      1279584000
# 117                            A Loving Companion Book      1387152000
# 118                                    Read Every Year      1331251200
# 119                           Never tire of this book!      1355356800
# 120                                   Insightful Prose       957571200
# 121                                           adequate      1219708800
# 122                                           Profound      1315872000
# 123                                 A bit disappointed      1112313600
# 124                            This Wisdom is timeless      1355961600
# 125                                   Magic Thoughts!!      1367625600
#
#       reviewTime
# 95    10 7, 2013
# 96    03 1, 2009
# 97    12 2, 2013
# 98   06 14, 2014
# 99   07 15, 2011
# 100  02 27, 2003
# 101   10 3, 2003
# 102   07 3, 2007
# 103  11 10, 2000
# 104   08 6, 2011
# 105   03 9, 2014
# 106   04 9, 2007
# 107  09 17, 2004
# 108  02 20, 2000
# 109   04 7, 2014
# 110  03 10, 2011
# 111  07 28, 2010
# 112  12 29, 2007
# 113  07 22, 2012
# 114  01 17, 2006
# 115  11 17, 2004
# 116  07 20, 2010
# 117  12 16, 2013
# 118   03 9, 2012
# 119  12 13, 2012
# 120   05 6, 2000
# 121  08 26, 2008
# 122  09 13, 2011
# 123   04 1, 2005
# 124  12 20, 2012
# 125   05 4, 2013

# %%
og_df_subset['x'] = [x for [x,y] in og_df_subset.helpful]
og_df_subset['y'] = [y for [x,y] in og_df_subset.helpful]
og_df_subset.drop(columns = ['helpful', 'reviewTime', 'reviewerName'], inplace=True)
og_df_subset
# Out:
#          reviewerID        asin  \
# 95    AAFLZI7MX9UIG  000100039X
# 96    A1FQPOYRBTTK1  000100039X
# 97   A1JBOMEZBH80JU  000100039X
# 98    A2DFYTW62P25Z  000100039X
# 99   A2MPRPCAQLTR3L  000100039X
# 100   A2W6WXEUAVM3E  000100039X
# 101   A7GT0WQKKDP0V  000100039X
# 102   ATAPOART4QGVO  000100039X
# 103  A2052JNVUPRTMT  000100039X
# 104   ADT39C7GOEAWW  000100039X
# 105   ASW9FWXSGKV2C  000100039X
# 106   AGKPTMTR3UX1R  000100039X
# 107  A1HS49P9TZRGV9  000100039X
# 108   AMFSDTN7LJ4EM  000100039X
# 109  A3Q5B6YEMGK4HI  000100039X
# 110  A2W4TXYV1M7FQ4  000100039X
# 111   AYZLXLVMJGTJV  000100039X
# 112   AG74166FELW9U  000100039X
# 113  A2W53LAQBPR831  000100039X
# 114  A2ZZHMT58ZMVCZ  000100039X
# 115   A5K32C2QZN3WL  000100039X
# 116  A1VSHT4FFP768T  000100039X
# 117   A4KYR93C6D5AI  000100039X
# 118    AQDD7PB1Z8ND  000100039X
# 119  A157UENZPTI1TD  000100039X
# 120  A3W43PSHRIG8KV  000100039X
# 121  A3HLNFF21USD1K  000100039X
# 122  A1P5UBFPQ48OWN  000100039X
# 123   AACNFH28C1ZHB  000100039X
# 124   AO3IVXXU3T4R3  000100039X
# 125   ANWMXAZZR2J0A  000100039X
#
#                                             reviewText  overall  \
# 95   Slow reading but full of Significant messages....      5.0
# 96   The Prophet by Kahlil Gibran is a book that's ...      5.0
# 97   This is a classic of world literature.  Everyo...      5.0
# 98   I was in my twenties when I first read The Pro...      5.0
# 99   A book to be treasured. A tremendous poet deal...      5.0
# 100  I read it in an hour. Kahlil Gibran is definit...      5.0
# 101  Reading a classic such as &quot;The Prophet&qu...      5.0
# 102  Maybe I just wasn't in the right mood for a he...      3.0
# 103  Gibran gets right down to the bedrock of what ...      5.0
# 104  The book came in great condition, as well as, ...      4.0
# 105  A short and magnificent book that will forever...      5.0
# 106  Kahlil Gibran (1883-1931), the Lebanese-Americ...      5.0
# 107  My father has this huge book collection and I ...      5.0
# 108  This is Kahlil Gibran at his best.  The prophe...      5.0
# 109  My favorite book.  I used the passaged in my w...      5.0
# 110  received on time and thank you for rel good on...      5.0
# 111  This book takes different themes such as work,...      5.0
# 112  "A brilliant man's philosophy on love, marriag...      5.0
# 113  I wanted the book the Prophet as an anniversar...      4.0
# 114  A prophet has waited twelve years in a coastal...      5.0
# 115  This book was the first and only I've read by ...      4.0
# 116  Everyone carries an omnificent quality within ...      5.0
# 117  Since I first read The Prophet when I was a te...      5.0
# 118  I have been reading The Prophet every year for...      5.0
# 119  Needed to read this and could not find my old ...      5.0
# 120  I first became aware of Kahlil Gibran when I r...      4.0
# 121  I appreciate getting the book at the great pri...      1.0
# 122  I first read this book as a teenager. It has r...      5.0
# 123  I picked up this book after being inspired by ...      2.0
# 124  This was my favorite book when i was 19! So I ...      5.0
# 125  Great read! A book for the ages! Each little p...      5.0
#
#                                                summary  unixReviewTime    x  \
# 95                                           Wonderful      1381104000    0
# 96                                    Interesting book      1235865600    0
# 97   A must read for every young person, a joy and ...      1385942400    0
# 98                                Through four decades      1402704000    0
# 99                       Equalled only by Shakespeare!      1310688000    0
# 100                                           Timeless      1046304000    3
# 101                  To Be Experienced as Well as Read      1065139200    2
# 102                                     Now I'm Sleepy      1183420800    3
# 103                                        Pure Wisdom       973814400   97
# 104                                         Satisfied.      1312588800    0
# 105                                        None Better      1394323200    0
# 106                           "People of Orphalese..."      1176076800   17
# 107                                        My Bible...      1095379200    7
# 108                                        Spectacular       951004800    1
# 109                         A beautiful spiritual book      1396828800    0
# 110  satisfied good ole book in the condition you t...      1299715200    0
# 111          Helpful Tool in gaining insight to spirit      1280275200    1
# 112               Inspiringly simple but also deep ...      1198886400    0
# 113                       Found what I was looking for      1342915200    1
# 114                        Deeper than you can imagine      1137456000  207
# 115    Chapters and Chapters of Insight and Revelation      1100649600    4
# 116                        A book that creates change.      1279584000    2
# 117                            A Loving Companion Book      1387152000    1
# 118                                    Read Every Year      1331251200    0
# 119                           Never tire of this book!      1355356800    0
# 120                                   Insightful Prose       957571200  156
# 121                                           adequate      1219708800    0
# 122                                           Profound      1315872000    4
# 123                                 A bit disappointed      1112313600   10
# 124                            This Wisdom is timeless      1355961600    0
# 125                                   Magic Thoughts!!      1367625600    0
#
#        y
# 95     0
# 96     0
# 97     0
# 98     0
# 99     0
# 100    5
# 101    2
# 102   15
# 103  103
# 104    0
# 105    0
# 106   20
# 107    9
# 108    2
# 109    0
# 110    0
# 111    1
# 112    1
# 113    1
# 114  215
# 115    5
# 116    2
# 117    1
# 118    0
# 119    0
# 120  167
# 121   56
# 122    4
# 123   28
# 124    0
# 125    0

# %% [markdown]
# ### Reuploading the original json file as csv

# %%
reader = pd.read_json('/Users/Sangeetha/Downloads/reviews_Books_5.json.gz',
                      compression = 'gzip', lines=True, chunksize=10000)

counter = 0
for data in reader:
    if counter < 10000:
        data['helpful_votes'] = [x for [x, y] in data.helpful]
        data['total_votes'] = [y for [x, y] in data.helpful]
        data.drop(columns=['reviewTime', 'helpful', 'reviewerName'], inplace=True)
        data.to_csv('/Volumes/external/Sangeetha-Project/reviews_clean.csv',
                          header=False, index=True, mode='a')
    else:
        break
        
    counter+=10000
    print(counter)
# Out:
# Index(['reviewerID', 'asin', 'reviewText', 'overall', 'summary',
#        'unixReviewTime', 'helpful_votes', 'total_votes'],
#       dtype='object')
# 0
# 10000

# %% [markdown]
# ### Checking the pos_votes isn't negative -TURNS OUT I WAS CASTING WRONG INT TYPE

# %%
check_df = pd.read_csv('/Volumes/external/Sangeetha-Project/reviews_clean.csv',
                 names=['reviwerId', 'asin', 'review', 'rating',
                        'summary', 'unixtime', 'pos_votes', 'total_votes'], nrows = 1000) \
    .drop(columns=['review', 'summary', 'unixtime']) \
    .astype({'rating': 'int8', 'pos_votes': 'int8', 'total_votes': 'int8'})

# %%
check_df[(check_df.reviwerId == 'A2ZZHMT58ZMVCZ')&(check_df.asin == '000100039X')]
# Out:
#           reviwerId        asin  rating  pos_votes  total_votes
# 114  A2ZZHMT58ZMVCZ  000100039X       5        -49          -41
